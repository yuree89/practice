# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d

# %% [markdown]
# ##1. 브랜드(표현력/이미지)

# %%
# 각 항목들의 점수 초기화
x = np.array([5, 4, 3, 1, 2])
y = np.array([5, 4, 3, 2, 1])
names = ['Hackers', 'Eduwill', 'WowPass', 'Inflearn', 'FastCampus']

# 와우패스와 각 항목들 간의 유클리디안 거리 계산
wowpass_scores = np.array([3, 3])
distances = np.sqrt(np.sum((np.vstack((x, y)).T - wowpass_scores) ** 2, axis=1))

# 결과 출력
for i, name in enumerate(names):
    print(f'{name}와 WowPass 간의 거리: {distances[i]:.2f}')
# Out:
# Hackers와 WowPass 간의 거리: 2.83
# Eduwill와 WowPass 간의 거리: 1.41
# WowPass와 WowPass 간의 거리: 0.00
# Inflearn와 WowPass 간의 거리: 2.24
# FastCampus와 WowPass 간의 거리: 2.24

# %%
import matplotlib.pyplot as plt

# 각 항목별 점수를 리스트로 정의
x = [5, 4, 3, 2, 1]
y = [5, 4, 3, 1, 2]

# 각 항목별 색상을 리스트로 정의
colors = ['blue', 'yellow', 'purple', 'green', 'red']

# 산점도 그리기
fig, ax = plt.subplots()
ax.scatter(x, y, c=colors)

# 각 점의 이름 표시
labels = ['Hackers', 'Eduwill', 'WowPass', 'Inflearn', 'FastCampus']
for i, label in enumerate(labels):
    ax.annotate(label, (x[i], y[i]))

# 그래프 보이기
plt.show()

# %% [markdown]
# ##2-1. 자격증 시장에서의 상품(서비스 수준/제품의 다양성/가격)

# %%
import numpy as np

# 각 항목들의 점수 초기화
x = np.array([5, 3, 4, 2, 1])
y = np.array([4, 5, 3, 2, 1])
z = np.array([2, 1, 3, 5, 4])
names = ['Hackers', 'Eduwill', 'WowPass', 'Inflearn', 'FastCampus']

# 와우패스와 각 항목들 간의 유클리디안 거리 계산
wowpass_scores = np.array([z[names.index('WowPass')], y[names.index('WowPass')], x[names.index('WowPass')]])
distances = np.sqrt(np.sum((np.vstack((z, y, x)).T - wowpass_scores) ** 2, axis=1))

# 결과 출력
for i, name in enumerate(names):
    print(f'{name}와 WowPass 간의 거리: {distances[i]:.2f}')
# Out:
# Hackers와 WowPass 간의 거리: 1.73
# Eduwill와 WowPass 간의 거리: 3.00
# WowPass와 WowPass 간의 거리: 0.00
# Inflearn와 WowPass 간의 거리: 3.00
# FastCampus와 WowPass 간의 거리: 3.74

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt

x = [5, 3, 4, 2, 1]
y = [4, 5, 3, 2, 1]
z = [2, 1, 3, 5, 4]
names = ['Hackers', 'Eduwill', 'WowPass', 'Inflearn', 'FastCampus']
colors = ['blue', 'yellow', 'purple', 'green', 'red']

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

for i in range(len(names)):
    ax.scatter(x[i], y[i], z[i], s=100, c=colors[i])
    ax.text(x[i], y[i], z[i], names[i], fontsize=12)

ax.set_xlabel('Service')
ax.set_ylabel('Product(Certificate)')
ax.set_zlabel('Price')

plt.show()

# %% [markdown]
# ##2-2. 실무 경험에서의 상품(서비스 수준/제품의 다양성/가격)

# %%
# 각 항목들의 점수 초기화
x = np.array([5, 3, 4, 2, 1])
y = np.array([3, 2, 1, 4, 5])
z = np.array([2, 1, 3, 5, 4])
names = ['Hackers', 'Eduwill', 'WowPass', 'Inflearn', 'FastCampus']

# 와우패스와 각 항목들 간의 유클리디안 거리 계산
wowpass_scores = np.array([z[names.index('WowPass')], y[names.index('WowPass')], x[names.index('WowPass')]])
distances = np.sqrt(np.sum((np.vstack((z, y, x)).T - wowpass_scores) ** 2, axis=1))

# 결과 출력
for i, name in enumerate(names):
    print(f'{name}와 WowPass 간의 거리: {distances[i]:.2f}')
# Out:
# Hackers와 WowPass 간의 거리: 2.45
# Eduwill와 WowPass 간의 거리: 2.45
# WowPass와 WowPass 간의 거리: 0.00
# Inflearn와 WowPass 간의 거리: 4.12
# FastCampus와 WowPass 간의 거리: 5.10

# %%
x = [5, 3, 4, 1, 2]
y = [3, 2, 1, 5, 4]
z = [3, 2, 1, 5, 4]
names = ['Hackers', 'Eduwill', 'WowPass', 'Inflearn', 'FastCampus']
colors = ['blue', 'yellow', 'purple', 'green', 'red']

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

for i in range(len(names)):
    ax.scatter(x[i], y[i], z[i], s=100, c=colors[i])
    ax.text(x[i], y[i], z[i], names[i], fontsize=12)

ax.set_xlabel('Service')
ax.set_ylabel('Product(Certificate)')
ax.set_zlabel('Price')

plt.show()

# %% [markdown]
# ##3. 소비자(브랜드 인지도/브랜드 SNS 인지도)

# %%
x = np.array([4, 5, 1, 2, 3])
y = np.array([5, 4, 1, 2, 3])
names = ['Hackers', 'Eduwill', 'WowPass', 'Inflearn', 'FastCampus']

wowpass_scores = np.array([3, 3])
distances = np.sqrt(np.sum((np.vstack((x, y)).T - wowpass_scores) ** 2, axis=1))

for i, name in enumerate(names):
    print(f'{name}와 WowPass 간의 거리: {distances[i]:.2f}')
# Out:
# Hackers와 WowPass 간의 거리: 2.24
# Eduwill와 WowPass 간의 거리: 2.24
# WowPass와 WowPass 간의 거리: 2.83
# Inflearn와 WowPass 간의 거리: 1.41
# FastCampus와 WowPass 간의 거리: 0.00

# %%
import matplotlib.pyplot as plt

# 각 항목별 점수를 리스트로 정의
x = [4, 5, 1, 3, 2]
y = [5, 4, 1, 3, 2]

# 각 항목별 색상을 리스트로 정의
colors = ['blue', 'yellow', 'purple', 'green', 'red']

# 산점도 그리기
fig, ax = plt.subplots()
ax.scatter(x, y, c=colors)

# 각 점의 이름 표시
labels = ['Hackers', 'Eduwill', 'WowPass', 'Inflearn', 'FastCampus']
for i, label in enumerate(labels):
    ax.annotate(label, (x[i], y[i]))

# 그래프 보이기
plt.show()
